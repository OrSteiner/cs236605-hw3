# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bm}[1]{{\bf #1}}
# \newcommand{\bb}[1]{\bm{\mathrm{#1}}}
# $$
#
# # Part 2: Variational Autoencoder
# <a id=part2></a>

# %% [markdown]
# In this part we will learn to generate new data using a special type of autoencoder model which allows us to
# sample from it's latent space. We'll implement and train a VAE and use it to generate new images.

# %%
import unittest
import os
import sys
import pathlib
import urllib
import shutil
import re
import zipfile

import numpy as np
import torch
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

test = unittest.TestCase()
plt.rcParams.update({'font.size': 12})
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Obtaining the dataset
# <a id=part2_1></a>

# %% [markdown]
# Let's begin by downloading a dataset of images that we want to learn to generate.
# We'll use the [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) (LFW) dataset which contains many labels faces of famous individuals.
#
# We're going to train our generative model to generate a specific face, not just any face.
# Since the person with the most images in this dataset is former president George W. Bush, we'll set out to train a Bush Generator :)
#
# However, if you feel adventurous and/or prefer to generate something else, feel free to edit the `PART2_CUSTOM_DATA_URL` variable in `hw3/answers.py`.

# %%
import cs236605.plot as plot
import cs236605.download
from hw3.answers import PART2_CUSTOM_DATA_URL as CUSTOM_DATA_URL

DATA_DIR = pathlib.Path.home().joinpath('.pytorch-datasets')
if CUSTOM_DATA_URL is None:
    DATA_URL = 'http://vis-www.cs.umass.edu/lfw/lfw-bush.zip'
else:
    DATA_URL = CUSTOM_DATA_URL

_, dataset_dir = cs236605.download.download_data(out_path=DATA_DIR, url=DATA_URL, extract=True, force=False)
# Out:
# File /home/shaigue/.pytorch-datasets/lfw-bush.zip exists, skipping download.
# Extracting /home/shaigue/.pytorch-datasets/lfw-bush.zip...
# Extracted 531 to /home/shaigue/.pytorch-datasets/lfw/George_W_Bush

# %% [markdown]
# Create a `Dataset` object that will load the extraced images:

# %%
import torchvision.transforms as T
from torchvision.datasets import ImageFolder

im_size = 64
tf = T.Compose([
    # Resize to constant spatial dimensions
    T.Resize((im_size, im_size)),
    # PIL.Image -> torch.Tensor
    T.ToTensor(),
    # Dynamic range [0,1] -> [-1, 1]
    T.Normalize(mean=(.5,.5,.5), std=(.5,.5,.5)),
])

ds_gwb = ImageFolder(os.path.dirname(dataset_dir), tf)

# %% [markdown]
# OK, let's see what we got. You can run the following block multiple times to display a random subset of images from the dataset.

# %%
_ = plot.dataset_first_n(ds_gwb, 50, figsize=(10,5), nrows=5)
print(f'Found {len(ds_gwb)} images in dataset folder.')
# Out:
# Found 530 images in dataset folder.

# %%
x0, y0 = ds_gwb[0]
x0 = x0.unsqueeze(0).to(device)
print(x0.shape)

test.assertSequenceEqual(x0.shape, (1, 3, im_size, im_size))
# Out:
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# ## The Variational Autoencoder
# <a id=part2_2></a>

# %% [markdown]
# An autoencoder is a model which learns a representation of data in an **unsupervised** fashion (i.e without any labels).
# Recall it's general form from the lecture:
#
# <img src="imgs/autoencoder.jpg"/>

# %% [markdown]
# An autoencoder maps an instance $\bb{x}$ to a **latent-space** representation $\bb{z}$.
# It has an encoder part, $\Phi_{\bb{\alpha}}(\bb{x})$ (a neural net with parameters $\bb{\alpha}$)
# and a decoder part, $\Psi_{\bb{\beta}}(\bb{z})$ (a neural net with parameters $\bb{\beta}$).
#
# While autoencoders can learn useful representations,
# generally it's hard to use them as generative models because there's no distribution we can sample from in the latent space. In other words, we have no way to choose a point $\bb{z}$ in the latent space
# such that $\Psi(\bb{z})$ will end up on the data manifold in the instance space.
#
# <img src="imgs/ae_sampling.jpg"/>

# %% [markdown]
# The variational autoencoder (VAE), first proposed by [Kingma and Welling](https://arxiv.org/pdf/1312.6114.pdf), addresses this issue by taking a probabilistic perspective.
# Briefly, a VAE model can be described as follows.
#
# We define, in Baysean terminology,
# - The **prior** distribution $p(\bb{Z})$ on points in the latent space.
# - The **likelihood** distribution of a sample $\bb{X}$ given a latent-space representation: $p(\bb{X}|\bb{Z})$.
# - The **posterior** distribution of points in the latent spaces given a specific instance: $p(\bb{Z}|\bb{X})$.
# - The **evidence** distribution $p(\bb{X})$ which is the distribution of the instance space due to the generative process.

# %% [markdown]
# To create our variational **decoder** we'll further specify:
#
# - A parametric likelihood distribution, $p _{\bb{\beta}}(\bb{X} | \bb{z}) = \mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$. The interpretation is that given a latent $\bb{z}$, we map it to a point normally distributed around the point calculated by our decoder neural network. Note that here $\sigma^2$ is a hyperparameter while $\vec{\beta}$ represents the network parameters.
# - A fixed latent-space prior distribution of $p(\bb{Z}) = \mathcal{N}(\bb{0},\bb{I})$.
#
# This setting allows us to generate a new instance $\bb{x}$ by sampling $\bb{z}$ from the multivariate normal
# distribution, obtaining the instance-space mean $\Psi _{\bb{\beta}}(\bb{z})$ using our decoder network,
# and then sampling $\bb{x}$ from $\mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$.

# %% [markdown]
# Our variational **encoder** will approximate the posterior with a parametric distribution
# $q _{\bb{\alpha}}(\bb{Z} | \bb{x}) \sim
# \mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$.
# The interpretation is that our encoder neural network, $\Phi_{\vec{\alpha}}(\bb{x})$, calculates
# the mean and variance of the posterior distribution, and samples $\bb{z}$ based on them.
# An important nuance here is that our network can't contain any stochastic elements that
# depend on the model parameters, otherwise we won't be able to back-propagate to those parameters.
# So sampling $\bb{z}$ from $\mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$ is not an option.
# The solution is to use what's known as the **reparametrization trick**: sample from an isotropic Gaussian,
# i.e. $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$ (which doesn't depend on trainable parameters), and calculate the latent representation as
# $\bb{z} = \bb{\mu} _{\bb{\alpha}}(\bb{x}) + \bb{u}\odot\bb{\sigma}^2_{\bb{\alpha}}(\bb{x})$.

# %% [markdown]
# To train a VAE model, we would like to maximize the evidence, $p(\bb{X})$, because
# $
# p(\bb{X}) = \int p(\bb{X}|{\bb{z}})p(\bb{z})d\bb{z}
# $
# thus maximizing the likelihood of generated instances from over the entire latent space.
#
# The **VAE loss** can therefore be stated as minimizing $\mathcal{L} = -\mathbb{E}_{\bb{x}} \log p(\bb{X})$.
# As we saw in the lecture, this expectation is intractable,
# but we can obtain a lower-bound for $p(\bb{X})$ (the evidence lower bound, "ELBO"):
#
# $$
# \log p(\bb{X}) \ge \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }( \log  p _{\bb{\beta}}(\bb{X} | \bb{z}) )
# -  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{X})\,\left\|\, p(\bb{Z} )\right.\right)
# $$
#
# where
# $
# \mathcal{D} _{\mathrm{KL}}(q\left\|\right.p) =
# \mathbb{E}_{\bb{z}\sim q}\left[ \log \frac{q(\bb{Z})}{p(\bb{Z})} \right]
# $
# is the Kullback-Liebler divergence, which can be interpreted as the information gained by using the posterior $q(\bb{Z|X})$ instead of the prior distribution $p(\bb{Z})$.
#
# Using the ELBO, the VAE loss becomes,
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ -\log  p _{\bb{\beta}}(\bb{x} | \bb{z}) \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$
#
# By remembering that the likelihood is a Gaussian distribution with a diagonal covariance and by applying the reparametrization trick, we can write the above as
#
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }
# \left[
# \frac{1}{2\sigma^2}\left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  + \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2
# \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$

# %% [markdown]
# ### Model Implementation
# <a id=part2_3></a>

# %% [markdown]
# Obviously our model will have two parts, an encoder and a decoder.
# Since we're working with images, we'll implement both as deep **convolutional** networks, where the decoder is a "mirror image" of the encoder implemented with adjoint (AKA transposed) convolutions.
# Between the encoder CNN and the decoder CNN we'll implement the sampling from
# the parametric posterior approximator $q_{\bb{\alpha}}(\bb{Z}|\bb{x})$
# to make it a VAE model and not just a regular autoencoder (of course, this is not yet enough to create a VAE,
# since we also need a special loss function which we'll get to later).

# %% [markdown]
# First let's implement just the CNN part of the Encoder network
# (this is not the full $\Phi_{\vec{\alpha}}(\bb{x})$ yet).
# As usual, it should take an input image and map to a activation volume of a specified depth.
# We'll consider this volume as the features we extract from the input image.
# Later we'll use these to create the latent space representation of the input.
# which will be our latent space representation.

# %% [markdown]
# **TODO**: Implement the `EncoderCNN` class in the `hw3/autoencoder.py` module.
# Implement any CNN architecture you like. If you need "architecture inspiration" you can see e.g. [this](https://arxiv.org/pdf/1512.09300.pdf) or [this](https://arxiv.org/pdf/1511.06434.pdf) paper.

# %%
import hw3.autoencoder as autoencoder

in_channels = 3
out_channels = 1024
encoder_cnn = autoencoder.EncoderCNN(in_channels, out_channels).to(device)
print(encoder_cnn)

h = encoder_cnn(x0)
print(h.shape)

test.assertEqual(h.dim(), 4)
test.assertSequenceEqual(h.shape[0:2], (1, out_channels))
# Out:
# EncoderCNN(
#   (cnn): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (1): ReLU()
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(256, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (4): ReLU()
#     (5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Conv2d(512, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (7): ReLU()
#     (8): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# torch.Size([1, 1024, 8, 8])

# %% [markdown]
# Now let's implement the CNN part of the Decoder.
# Again this is not yet the full $\Psi _{\bb{\beta}}(\bb{z})$. It should take an activation volume produced
# by your `EncoderCNN` and output an image of the same dimensions as the Encoder's input was.
# This should be a CNN which is a "mirror image" of the the Encoder. For example, replace convolutions with transposed convolutions, downsampling with up-sampling etc.
# Consult the documentation of [ConvTranspose2D](https://pytorch.org/docs/0.4.1/nn.html#convtranspose2d)
# to figure out how to reverse your convolutional layers in terms of input and output dimensions.

# %% [markdown]
# **TODO**: Implement the `DecoderCNN` class in the `hw3/autoencoder.py` module.

# %%
decoder_cnn = autoencoder.DecoderCNN(in_channels=out_channels, out_channels=in_channels).to(device)
print(decoder_cnn)
print(h.shape)
x0r = decoder_cnn(h)
print(x0r.shape)

test.assertEqual(x0.shape, x0r.shape)

# Should look like colored noise
T.functional.to_pil_image(x0r[0].cpu().detach())
# Out:
# DecoderCNN(
#   (cnn): Sequential(
#     (0): ConvTranspose2d(1024, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(1024, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ConvTranspose2d(512, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (7): ReLU()
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): Conv2d(256, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   )
# )
# torch.Size([1, 1024, 8, 8])
# torch.Size([1, 3, 64, 64])
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F7119FA7C88>

# %% [markdown]
# Let's now implement the full VAE Encoder, $\Phi_{\vec{\alpha}}(\vec{x})$.
# It will work as follows:
# 1. Produce a feature vector $\vec{h}$ from the input image $\vec{x}$.
# 2. Use two affine transforms to convert the features into the mean and log-variance of the posterior, i.e.
#     $$
#     \begin{align}
#         \bb{\mu} _{\bb{\alpha}}(\bb{x}) &= \vec{h}\mattr{W}_{\mathrm{h\mu}} + \vec{b}_{\mathrm{h\mu}} \\
#         \log\left(\bb{\sigma}^2_{\bb{\alpha}}(\bb{x})\right) &= \vec{h}\mattr{W}_{\mathrm{h\sigma^2}} + \vec{b}_{\mathrm{h\sigma^2}}
#     \end{align}
#     $$
# 3. Use the **reparametrization trick** to create the latent representation $\vec{z}$.
#
# Note that we model the **log** of the variance, not the actual variance.
# The reason is that the log is easier to optimize, since (a) It doesn't have to be positive, and (b) it has a much larger dynamic range.
# The above formulation is proposed in appendix C of the [VAE paper](https://arxiv.org/pdf/1312.6114.pdf).

# %% [markdown]
# **TODO**: Implement the `encode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`.

# %%
z_dim = 2
vae = autoencoder.VAE(encoder_cnn, decoder_cnn, x0[0].size(), z_dim).to(device)
print(vae)

z, mu, log_sigma2 = vae.encode(x0)

test.assertSequenceEqual(z.shape, (1, z_dim))
# print(z.dim())
test.assertTrue(z.shape == mu.shape == log_sigma2.shape)

print(f'mu(x0)={list(*mu.detach().cpu().numpy())}, sigma2(x0)={list(*torch.exp(log_sigma2).detach().cpu().numpy())}')

# Sample from q(Z|x)
N = 500
Z = torch.zeros(N, z_dim)
_, ax = plt.subplots()
with torch.no_grad():
    for i in range(500):
        Z[i], _, _ = vae.encode(x0)
        ax.scatter(*Z[i].cpu().numpy())

# Should be close to the above
print('sampled mu', torch.mean(Z, dim=0))
print('sampled sigma2', torch.var(Z, dim=0))
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (1): ReLU()
#       (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(256, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (4): ReLU()
#       (5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Conv2d(512, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (7): ReLU()
#       (8): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): ConvTranspose2d(1024, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (1): ReLU()
#       (2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ConvTranspose2d(1024, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (4): ReLU()
#       (5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ConvTranspose2d(512, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (7): ReLU()
#       (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): Conv2d(256, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#   )
#   (Linear_mu): Sequential(
#     (0): Linear(in_features=65536, out_features=2, bias=True)
#     (1): Sigmoid()
#   )
#   (Linear_log_sigma2): Sequential(
#     (0): Linear(in_features=65536, out_features=2, bias=True)
#     (1): Sigmoid()
#   )
#   (Linear_z_h): Sequential(
#     (0): Linear(in_features=2, out_features=65536, bias=True)
#     (1): Sigmoid()
#   )
# )
# mu(x0)=[0.52492577, 0.5741457], sigma2(x0)=[1.4644281, 1.6772923]
# sampled mu tensor([0.5327, 0.7299])
# sampled sigma2 tensor([2.0183, 2.9241])

# %% [markdown]
# Let's now implement the full VAE Decoder, $\Psi _{\bb{\beta}}(\bb{z})$.
# It will work as follows:
# 1. Produce a feature vector $\tilde{\vec{h}}$ from the latent vector $\vec{z}$ using an affine transform.
# 2. Reconstruct an image $\tilde{\vec{x}}$ from $\tilde{\vec{h}}$.

# %% [markdown]
# **TODO**: Implement the `decode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`. You may need to also re-run the block above after you implement this.

# %%
x0r = vae.decode(z)

test.assertSequenceEqual(x0r.shape, x0.shape)

# %% [markdown]
# Our model's `forward()` function will simply return `decode(encode(x))` as well as the calculated mean and log-variance of the posterior.

# %%
x0r, mu, log_sigma2 = vae(x0)

test.assertSequenceEqual(x0r.shape, x0.shape)
test.assertSequenceEqual(mu.shape, (1, z_dim))
test.assertSequenceEqual(log_sigma2.shape, (1, z_dim))
T.functional.to_pil_image(x0r[0].detach().cpu())
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F71180D75C0>

# %% [markdown]
# ### Loss Implementation
# <a id=part2_4></a>

# %% [markdown]
# In practice, since we're using SGD, we'll drop the expectation over $\bb{X}$ and instead sample an instance from the training set and compute a point-wise loss. Similarly, we'll drop the expectation over $\bb{Z}$ by sampling from $q_{\vec{\alpha}}(\bb{Z}|\bb{x})$.
# Additionally, because the KL divergence is between two Gaussian distributions, there is a closed-form expression for it. These points bring us to the following point-wise loss:
#
# $$
# \ell(\vec{\alpha},\vec{\beta};\bb{x}) =
# \frac{1}{\sigma^2} \left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  +
# \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2 +
# \mathrm{tr}\,\bb{\Sigma} _{\bb{\alpha}}(\bb{x}) +  \|\bb{\mu} _{\bb{\alpha}}(\bb{x})\|^2 _2 - d_z - \log\det \bb{\Sigma} _{\bb{\alpha}}(\bb{x})
# $$
#
# where $d_z$ is the dimension of the latent space. This pointwise loss is the quantity that we'll compute and minimize with gradient descent.

# %% [markdown]
# **TODO**: Implement the `vae_loss()` function in the `hw3/autoencoder.py` module.

# %%
from hw3.autoencoder import vae_loss
torch.manual_seed(42)

def test_vae_loss():
    # Test data
    N, C, H, W = 10, 3, 64, 64 
    z_dim = 32
    x  = torch.randn(N, C, H, W)*2 - 1
    xr = torch.randn(N, C, H, W)*2 - 1
    z_mu = torch.randn(N, z_dim)
    z_log_sigma2 = torch.randn(N, z_dim)
    x_sigma2 = 0.9
    
    loss, _, _ = vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)
    
    test.assertAlmostEqual(loss.item(), 58.3234367, delta=1e-3)
    return loss

test_vae_loss()
# Out:
# tensor(58.3234)

# %% [markdown]
# ### Sampling
# <a id=part2_5></a>

# %% [markdown]
# The main advantage of a VAE is that it can by used as a generative model by sampling the latent space, since
# we optimize for a Normal prior $p(\bb{Z})$ in the loss function. Let's now implement this so that we can visualize how our model is doing when we train.

# %% [markdown]
# **TODO**: Implement the `sample()` method in the `VAE` class within the `hw3/autoencoder.py` module.

# %%
samples = vae.sample(5)
_ = plot.tensors_as_images(samples)

# %% [markdown]
# ### Training
# <a id=part2_6></a>

# %% [markdown]
# Time to train!

# %% [markdown]
# **TODO**:
# 1. Implement the `VAETrainer` class in the `hw3/training.py` module. Make sure to implement the `checkpoints` feature of the `Trainer` class if you haven't done so already in Part 1.
# 2. Tweak the hyperparameters in the `part2_vae_hyperparam()` function within the `hw3/answers.py` module.

# %%
import torch.optim as optim
from torch.utils.data import random_split
from torch.utils.data import DataLoader
from torch.nn import DataParallel
from hw3.training import VAETrainer
from hw3.answers import part2_vae_hyperparams

torch.manual_seed(42)

# Hyperparams
hp = part2_vae_hyperparams()
batch_size = hp['batch_size']
h_dim = hp['h_dim']
z_dim = hp['z_dim']
x_sigma2 = hp['x_sigma2']
learn_rate = hp['learn_rate']
betas = hp['betas']

# Data
split_lengths = [int(len(ds_gwb)*0.9), int(len(ds_gwb)*0.1)]
ds_train, ds_test = random_split(ds_gwb, split_lengths)
dl_train = DataLoader(ds_train, batch_size, shuffle=True)
dl_test  = DataLoader(ds_test,  batch_size, shuffle=True)
im_size = ds_train[0][0].shape

# Model
encoder = autoencoder.EncoderCNN(in_channels=im_size[0], out_channels=h_dim)
decoder = autoencoder.DecoderCNN(in_channels=h_dim, out_channels=im_size[0])
vae = autoencoder.VAE(encoder, decoder, im_size, z_dim)
vae_dp = DataParallel(vae).to(device)

# Optimizer
optimizer = optim.Adam(vae.parameters(), lr=learn_rate, betas=betas)

# Loss
def loss_fn(x, xr, z_mu, z_log_sigma2):
    return autoencoder.vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)

# Trainer
trainer = VAETrainer(vae_dp, loss_fn, optimizer, device)
checkpoint_file = 'checkpoints/vae'
checkpoint_file_final = f'{checkpoint_file}_final'
if os.path.isfile(f'{checkpoint_file}.pt'):
    os.remove(f'{checkpoint_file}.pt')

# Show model and hypers
print(vae)
print(hp)
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (1): ReLU()
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (4): ReLU()
#       (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Conv2d(256, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (7): ReLU()
#       (8): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): ConvTranspose2d(512, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (1): ReLU()
#       (2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ConvTranspose2d(512, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (4): ReLU()
#       (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (7): ReLU()
#       (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): Conv2d(128, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#   )
#   (Linear_mu): Sequential(
#     (0): Linear(in_features=32768, out_features=32, bias=True)
#     (1): Sigmoid()
#   )
#   (Linear_log_sigma2): Sequential(
#     (0): Linear(in_features=32768, out_features=32, bias=True)
#     (1): Sigmoid()
#   )
#   (Linear_z_h): Sequential(
#     (0): Linear(in_features=32, out_features=32768, bias=True)
#     (1): Sigmoid()
#   )
# )
# {'batch_size': 32, 'h_dim': 512, 'z_dim': 32, 'x_sigma2': 0.001, 'learn_rate': 0.002, 'betas': (0.5, 0.999)}

# %% [markdown]
# **TODO**:
# 1. Run the following block to train. It will sample some images from your model every few epochs so you can see the progress.
# 2. When you're satisfied with your results, rename the checkpoints file by adding `_final`. When you run the `main.py` script to generate your submission, the final checkpoints file will be loaded instead of running training.

# %%
import IPython.display

def post_epoch_fn(epoch, train_result, test_result, verbose):
    # Plot some samples if this is a verbose epoch
    if verbose:
        samples = vae.sample(n=5)
        fig, _ = plot.tensors_as_images(samples, figsize=(6,2))
        IPython.display.display(fig)
        plt.close(fig)

if os.path.isfile(f'{checkpoint_file_final}.pt'):
    print(f'*** Loading final checkpoint file {checkpoint_file_final} instead of training')
    checkpoint_file = checkpoint_file_final
else:
    res = trainer.fit(dl_train, dl_test,
                      num_epochs=200, early_stopping=20, print_every=10,
                      checkpoints=checkpoint_file,
                      post_epoch_fn=post_epoch_fn)
    
# Plot images from best model
saved_state = torch.load(f'{checkpoint_file}.pt', map_location=device)
vae_dp.load_state_dict(saved_state['model_state'])
print('*** Images Generated from best model:')
fig, _ = plot.tensors_as_images(vae_dp.module.sample(n=15), nrows=3, figsize=(6,6))
# Out:
# --- EPOCH 1/200 ---
# train_batch (Avg. Loss 387.377, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.69it/s]
# test_batch (Avg. Loss 428.498, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.18it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 1
# train_batch (Avg. Loss 288.179, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.70it/s]
# test_batch (Avg. Loss 288.198, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.90it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 2
# train_batch (Avg. Loss 277.179, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.38it/s]
# test_batch (Avg. Loss 266.322, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.97it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 3
# train_batch (Avg. Loss 270.733, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.74it/s]
# test_batch (Avg. Loss 312.717, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.28it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 4
# train_batch (Avg. Loss 259.756, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.74it/s]
# test_batch (Avg. Loss 277.937, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.26it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 5
# train_batch (Avg. Loss 245.119, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.79it/s]
# test_batch (Avg. Loss 236.647, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.12it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 6
# train_batch (Avg. Loss 231.493, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.75it/s]
# test_batch (Avg. Loss 255.424, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.25it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 7
# train_batch (Avg. Loss 227.771, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.61it/s]
# test_batch (Avg. Loss 245.483, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.97it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 8
# train_batch (Avg. Loss 226.248, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.67it/s]
# test_batch (Avg. Loss 278.543, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.97it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 9
# train_batch (Avg. Loss 224.933, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.71it/s]
# test_batch (Avg. Loss 227.158, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.67it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 10
# --- EPOCH 11/200 ---
# train_batch (Avg. Loss 220.743, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.70it/s]
# test_batch (Avg. Loss 235.129, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.27it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 11
# train_batch (Avg. Loss 224.116, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.75it/s]
# test_batch (Avg. Loss 232.096, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  8.12it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 12
# train_batch (Avg. Loss 215.433, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.63it/s]
# test_batch (Avg. Loss 232.283, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.84it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 13
# train_batch (Avg. Loss 220.223, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.67it/s]
# test_batch (Avg. Loss 225.766, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.30it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 14
# train_batch (Avg. Loss 215.259, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.61it/s]
# test_batch (Avg. Loss 232.471, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 15
# train_batch (Avg. Loss 216.727, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.60it/s]
# test_batch (Avg. Loss 226.358, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 16
# train_batch (Avg. Loss 214.064, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.70it/s]
# test_batch (Avg. Loss 228.936, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.45it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 17
# train_batch (Avg. Loss 212.844, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.49it/s]
# test_batch (Avg. Loss 227.997, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  4.58it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 18
# train_batch (Avg. Loss 214.977, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.96it/s]
# test_batch (Avg. Loss 234.930, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 19
# train_batch (Avg. Loss 213.233, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.08it/s]
# test_batch (Avg. Loss 223.266, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.10it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 20
# --- EPOCH 21/200 ---
# train_batch (Avg. Loss 211.182, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.25it/s]
# test_batch (Avg. Loss 225.569, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.26it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 21
# train_batch (Avg. Loss 210.495, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.58it/s]
# test_batch (Avg. Loss 222.051, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.18it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 22
# train_batch (Avg. Loss 209.801, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.61it/s]
# test_batch (Avg. Loss 219.916, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.77it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 23
# train_batch (Avg. Loss 210.554, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.39it/s]
# test_batch (Avg. Loss 221.801, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.50it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 24
# train_batch (Avg. Loss 209.820, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.55it/s]
# test_batch (Avg. Loss 236.685, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.06it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 25
# train_batch (Avg. Loss 210.323, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.65it/s]
# test_batch (Avg. Loss 235.342, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.18it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 26
# train_batch (Avg. Loss 207.162, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.65it/s]
# test_batch (Avg. Loss 221.139, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 27
# train_batch (Avg. Loss 209.048, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.60it/s]
# test_batch (Avg. Loss 219.094, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.93it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 28
# train_batch (Avg. Loss 205.131, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.57it/s]
# test_batch (Avg. Loss 226.282, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.95it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 29
# train_batch (Avg. Loss 209.741, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# test_batch (Avg. Loss 230.508, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.18it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 30
# --- EPOCH 31/200 ---
# train_batch (Avg. Loss 206.363, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.74it/s]
# test_batch (Avg. Loss 228.548, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.19it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 31
# train_batch (Avg. Loss 209.478, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.65it/s]
# test_batch (Avg. Loss 224.851, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 32
# train_batch (Avg. Loss 209.091, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.57it/s]
# test_batch (Avg. Loss 237.616, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.85it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 33
# train_batch (Avg. Loss 209.506, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.63it/s]
# test_batch (Avg. Loss 230.801, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.85it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 34
# train_batch (Avg. Loss 210.040, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.62it/s]
# test_batch (Avg. Loss 222.842, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.96it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 35
# train_batch (Avg. Loss 208.277, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.49it/s]
# test_batch (Avg. Loss 222.664, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 36
# train_batch (Avg. Loss 205.518, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.61it/s]
# test_batch (Avg. Loss 223.296, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 37
# train_batch (Avg. Loss 205.615, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.64it/s]
# test_batch (Avg. Loss 223.430, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 38
# train_batch (Avg. Loss 207.778, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.68it/s]
# test_batch (Avg. Loss 214.862, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.01it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 39
# train_batch (Avg. Loss 205.102, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.03it/s]
# test_batch (Avg. Loss 227.609, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.80it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 40
# --- EPOCH 41/200 ---
# train_batch (Avg. Loss 208.139, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.00it/s]
# test_batch (Avg. Loss 231.546, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.68it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 41
# train_batch (Avg. Loss 207.473, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.05it/s]
# test_batch (Avg. Loss 220.364, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.74it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 42
# train_batch (Avg. Loss 206.963, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.01it/s]
# test_batch (Avg. Loss 216.927, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.77it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 43
# train_batch (Avg. Loss 204.896, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.55it/s]
# test_batch (Avg. Loss 222.368, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.52it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 44
# train_batch (Avg. Loss 205.511, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.61it/s]
# test_batch (Avg. Loss 224.134, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 45
# train_batch (Avg. Loss 203.636, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.60it/s]
# test_batch (Avg. Loss 220.209, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.32it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 46
# train_batch (Avg. Loss 207.769, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.05it/s]
# test_batch (Avg. Loss 218.024, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.90it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 47
# train_batch (Avg. Loss 203.919, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.12it/s]
# test_batch (Avg. Loss 214.123, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.75it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 48
# train_batch (Avg. Loss 203.488, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.51it/s]
# test_batch (Avg. Loss 219.092, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.12it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 49
# train_batch (Avg. Loss 205.955, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.64it/s]
# test_batch (Avg. Loss 216.877, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.09it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 50
# --- EPOCH 51/200 ---
# train_batch (Avg. Loss 207.121, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.67it/s]
# test_batch (Avg. Loss 213.797, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.27it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 51
# train_batch (Avg. Loss 204.981, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.67it/s]
# test_batch (Avg. Loss 209.613, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.32it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 52
# train_batch (Avg. Loss 206.546, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.71it/s]
# test_batch (Avg. Loss 217.909, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.62it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 53
# train_batch (Avg. Loss 208.053, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.01it/s]
# test_batch (Avg. Loss 215.902, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.21it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 54
# train_batch (Avg. Loss 209.009, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.26it/s]
# test_batch (Avg. Loss 210.206, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.47it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 55
# train_batch (Avg. Loss 206.219, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.72it/s]
# test_batch (Avg. Loss 217.438, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 56
# train_batch (Avg. Loss 205.470, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.73it/s]
# test_batch (Avg. Loss 230.352, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.12it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 57
# train_batch (Avg. Loss 206.549, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.65it/s]
# test_batch (Avg. Loss 214.145, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.16it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 58
# train_batch (Avg. Loss 205.405, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.66it/s]
# test_batch (Avg. Loss 217.908, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 59
# train_batch (Avg. Loss 203.376, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.59it/s]
# test_batch (Avg. Loss 215.704, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.38it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 60
# --- EPOCH 61/200 ---
# train_batch (Avg. Loss 201.426, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.58it/s]
# test_batch (Avg. Loss 216.712, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.00it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 61
# train_batch (Avg. Loss 206.610, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.42it/s]
# test_batch (Avg. Loss 223.839, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.02it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 62
# train_batch (Avg. Loss 206.797, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# test_batch (Avg. Loss 217.809, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 63
# train_batch (Avg. Loss 203.943, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.94it/s]
# test_batch (Avg. Loss 218.549, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 64
# train_batch (Avg. Loss 202.784, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.09it/s]
# test_batch (Avg. Loss 222.793, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.51it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 65
# train_batch (Avg. Loss 203.646, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.99it/s]
# test_batch (Avg. Loss 214.486, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.75it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 66
# train_batch (Avg. Loss 205.406, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.25it/s]
# test_batch (Avg. Loss 214.543, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 67
# train_batch (Avg. Loss 206.451, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.18it/s]
# test_batch (Avg. Loss 229.759, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 68
# train_batch (Avg. Loss 202.690, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.67it/s]
# test_batch (Avg. Loss 217.759, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 69
# train_batch (Avg. Loss 209.254, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.55it/s]
# test_batch (Avg. Loss 211.610, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 70
# --- EPOCH 71/200 ---
# train_batch (Avg. Loss 206.051, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.63it/s]
# test_batch (Avg. Loss 214.327, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 71
# train_batch (Avg. Loss 202.384, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.62it/s]
# test_batch (Avg. Loss 212.507, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.05it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 72
# train_batch (Avg. Loss 202.279, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.65it/s]
# test_batch (Avg. Loss 217.643, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.05it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 73
# train_batch (Avg. Loss 202.129, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.60it/s]
# test_batch (Avg. Loss 231.133, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.95it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 74
# train_batch (Avg. Loss 203.973, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.57it/s]
# test_batch (Avg. Loss 216.398, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 75
# train_batch (Avg. Loss 199.401, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.68it/s]
# test_batch (Avg. Loss 217.788, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.16it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 76
# train_batch (Avg. Loss 202.711, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.62it/s]
# test_batch (Avg. Loss 221.956, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.83it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 77
# train_batch (Avg. Loss 201.230, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.55it/s]
# test_batch (Avg. Loss 219.040, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.04it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 78
# train_batch (Avg. Loss 201.999, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.56it/s]
# test_batch (Avg. Loss 209.340, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.29it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 79
# train_batch (Avg. Loss 199.004, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.67it/s]
# test_batch (Avg. Loss 213.201, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 80
# --- EPOCH 81/200 ---
# train_batch (Avg. Loss 200.875, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.62it/s]
# test_batch (Avg. Loss 222.312, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.82it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 81
# train_batch (Avg. Loss 202.396, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.67it/s]
# test_batch (Avg. Loss 216.851, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 82
# train_batch (Avg. Loss 205.228, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.70it/s]
# test_batch (Avg. Loss 210.168, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.37it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 83
# train_batch (Avg. Loss 202.814, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.58it/s]
# test_batch (Avg. Loss 213.301, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 84
# train_batch (Avg. Loss 200.538, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.63it/s]
# test_batch (Avg. Loss 208.077, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 85
# train_batch (Avg. Loss 201.955, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.51it/s]
# test_batch (Avg. Loss 213.688, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.95it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 86
# train_batch (Avg. Loss 204.653, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.68it/s]
# test_batch (Avg. Loss 216.236, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.95it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 87
# train_batch (Avg. Loss 201.200, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.01it/s]
# test_batch (Avg. Loss 214.196, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 88
# train_batch (Avg. Loss 198.822, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.02it/s]
# test_batch (Avg. Loss 216.014, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.09it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 89
# train_batch (Avg. Loss 200.757, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.94it/s]
# test_batch (Avg. Loss 209.022, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.08it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 90
# --- EPOCH 91/200 ---
# train_batch (Avg. Loss 198.753, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.98it/s]
# test_batch (Avg. Loss 216.914, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.75it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 91
# train_batch (Avg. Loss 200.867, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.98it/s]
# test_batch (Avg. Loss 215.997, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 92
# train_batch (Avg. Loss 199.660, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.93it/s]
# test_batch (Avg. Loss 216.728, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.69it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 93
# train_batch (Avg. Loss 203.841, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.03it/s]
# test_batch (Avg. Loss 210.866, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.73it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 94
# train_batch (Avg. Loss 199.421, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.02it/s]
# test_batch (Avg. Loss 213.627, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 95
# train_batch (Avg. Loss 199.296, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.07it/s]
# test_batch (Avg. Loss 201.493, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.90it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 96
# train_batch (Avg. Loss 203.279, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.09it/s]
# test_batch (Avg. Loss 214.420, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.18it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 97
# train_batch (Avg. Loss 200.482, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.95it/s]
# test_batch (Avg. Loss 212.143, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.83it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 98
# train_batch (Avg. Loss 205.840, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.98it/s]
# test_batch (Avg. Loss 203.644, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.44it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 99
# train_batch (Avg. Loss 201.683, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.43it/s]
# test_batch (Avg. Loss 215.022, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.48it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 100
# --- EPOCH 101/200 ---
# train_batch (Avg. Loss 200.629, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.45it/s]
# test_batch (Avg. Loss 215.637, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 101
# train_batch (Avg. Loss 200.236, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.56it/s]
# test_batch (Avg. Loss 211.481, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.96it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 102
# train_batch (Avg. Loss 202.128, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.08it/s]
# test_batch (Avg. Loss 216.561, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.34it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 103
# train_batch (Avg. Loss 201.216, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.13it/s]
# test_batch (Avg. Loss 214.735, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.68it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 104
# train_batch (Avg. Loss 203.773, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.97it/s]
# test_batch (Avg. Loss 214.572, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.83it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 105
# train_batch (Avg. Loss 198.238, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.96it/s]
# test_batch (Avg. Loss 222.945, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.80it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 106
# train_batch (Avg. Loss 201.564, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  3.86it/s]
# test_batch (Avg. Loss 214.757, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.58it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 107
# train_batch (Avg. Loss 201.885, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.11it/s]
# test_batch (Avg. Loss 217.498, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 108
# train_batch (Avg. Loss 202.145, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.71it/s]
# test_batch (Avg. Loss 212.286, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.20it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 109
# train_batch (Avg. Loss 201.363, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.64it/s]
# test_batch (Avg. Loss 211.450, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 110
# --- EPOCH 111/200 ---
# train_batch (Avg. Loss 198.271, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.54it/s]
# test_batch (Avg. Loss 216.484, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.03it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 111
# train_batch (Avg. Loss 199.812, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.66it/s]
# test_batch (Avg. Loss 215.236, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.00it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 112
# train_batch (Avg. Loss 208.509, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.07it/s]
# test_batch (Avg. Loss 219.142, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.03it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 113
# train_batch (Avg. Loss 201.083, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  3.51it/s]
# test_batch (Avg. Loss 211.031, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 114
# train_batch (Avg. Loss 202.672, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.94it/s]
# test_batch (Avg. Loss 208.133, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.59it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 115
# train_batch (Avg. Loss 199.539, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.06it/s]
# test_batch (Avg. Loss 214.632, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.95it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 116
# train_batch (Avg. Loss 200.444, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.00it/s]
# test_batch (Avg. Loss 206.474, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.50it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 117
# train_batch (Avg. Loss 197.502, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  3.73it/s]
# test_batch (Avg. Loss 214.480, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.64it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 118
# train_batch (Avg. Loss 199.789, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.20it/s]
# test_batch (Avg. Loss 217.349, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.65it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 119
# train_batch (Avg. Loss 203.223, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.57it/s]
# test_batch (Avg. Loss 207.014, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.68it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 120
# --- EPOCH 121/200 ---
# train_batch (Avg. Loss 201.929, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.97it/s]
# test_batch (Avg. Loss 207.208, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.96it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 121
# train_batch (Avg. Loss 202.134, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.03it/s]
# test_batch (Avg. Loss 207.367, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.61it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 122
# train_batch (Avg. Loss 200.131, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.95it/s]
# test_batch (Avg. Loss 213.384, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 123
# train_batch (Avg. Loss 198.784, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.99it/s]
# test_batch (Avg. Loss 213.811, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 124
# train_batch (Avg. Loss 198.734, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.03it/s]
# test_batch (Avg. Loss 211.152, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 125
# train_batch (Avg. Loss 201.095, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.10it/s]
# test_batch (Avg. Loss 208.466, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.82it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 126
# train_batch (Avg. Loss 199.988, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.34it/s]
# test_batch (Avg. Loss 209.900, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.54it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 127
# train_batch (Avg. Loss 197.760, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.62it/s]
# test_batch (Avg. Loss 206.691, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.46it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 128
# train_batch (Avg. Loss 203.921, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.48it/s]
# test_batch (Avg. Loss 204.473, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 129
# train_batch (Avg. Loss 200.862, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.52it/s]
# test_batch (Avg. Loss 211.762, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.01it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 130
# --- EPOCH 131/200 ---
# train_batch (Avg. Loss 198.911, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.65it/s]
# test_batch (Avg. Loss 211.019, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.20it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 131
# train_batch (Avg. Loss 199.069, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.62it/s]
# test_batch (Avg. Loss 208.133, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.30it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 132
# train_batch (Avg. Loss 202.173, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.56it/s]
# test_batch (Avg. Loss 211.523, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.74it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 133
# train_batch (Avg. Loss 201.956, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.95it/s]
# test_batch (Avg. Loss 210.386, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 134
# train_batch (Avg. Loss 198.787, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.88it/s]
# test_batch (Avg. Loss 217.046, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.85it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 135
# train_batch (Avg. Loss 198.336, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.91it/s]
# test_batch (Avg. Loss 208.483, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.58it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 136
# train_batch (Avg. Loss 201.605, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.89it/s]
# test_batch (Avg. Loss 210.132, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.02it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 137
# train_batch (Avg. Loss 200.207, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.07it/s]
# test_batch (Avg. Loss 202.827, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.96it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 138
# train_batch (Avg. Loss 200.108, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.48it/s]
# test_batch (Avg. Loss 207.296, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.13it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 139
# train_batch (Avg. Loss 203.498, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.02it/s]
# test_batch (Avg. Loss 208.455, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 140
# --- EPOCH 141/200 ---
# train_batch (Avg. Loss 200.386, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  3.89it/s]
# test_batch (Avg. Loss 218.176, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 141
# train_batch (Avg. Loss 197.514, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.85it/s]
# test_batch (Avg. Loss 212.625, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 142
# train_batch (Avg. Loss 201.558, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.44it/s]
# test_batch (Avg. Loss 217.443, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.10it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 143
# train_batch (Avg. Loss 198.403, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# test_batch (Avg. Loss 206.443, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.91it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 144
# train_batch (Avg. Loss 199.016, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.64it/s]
# test_batch (Avg. Loss 211.492, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  3.14it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 145
# train_batch (Avg. Loss 203.483, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.55it/s]
# test_batch (Avg. Loss 208.504, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 146
# train_batch (Avg. Loss 204.106, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.15it/s]
# test_batch (Avg. Loss 206.634, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.06it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 147
# train_batch (Avg. Loss 200.093, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.61it/s]
# test_batch (Avg. Loss 207.964, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.87it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 148
# train_batch (Avg. Loss 200.522, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.53it/s]
# test_batch (Avg. Loss 234.680, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 149
# train_batch (Avg. Loss 200.823, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.63it/s]
# test_batch (Avg. Loss 214.891, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.55it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 150
# --- EPOCH 151/200 ---
# train_batch (Avg. Loss 202.944, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.63it/s]
# test_batch (Avg. Loss 204.826, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.01it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 151
# train_batch (Avg. Loss 197.148, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.19it/s]
# test_batch (Avg. Loss 211.036, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.61it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 152
# train_batch (Avg. Loss 199.491, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.06it/s]
# test_batch (Avg. Loss 200.892, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.54it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 153
# train_batch (Avg. Loss 200.021, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.05it/s]
# test_batch (Avg. Loss 204.117, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.97it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 154
# train_batch (Avg. Loss 199.806, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.63it/s]
# test_batch (Avg. Loss 209.616, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.97it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 155
# train_batch (Avg. Loss 204.587, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.58it/s]
# test_batch (Avg. Loss 220.534, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.20it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 156
# train_batch (Avg. Loss 204.334, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.74it/s]
# test_batch (Avg. Loss 212.164, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.32it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 157
# train_batch (Avg. Loss 203.299, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.02it/s]
# test_batch (Avg. Loss 211.800, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.04it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 158
# train_batch (Avg. Loss 204.099, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.95it/s]
# test_batch (Avg. Loss 201.898, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.70it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 159
# train_batch (Avg. Loss 203.009, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  4.06it/s]
# test_batch (Avg. Loss 214.301, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.86it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 160
# --- EPOCH 161/200 ---
# train_batch (Avg. Loss 205.053, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.06it/s]
# test_batch (Avg. Loss 210.637, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 161
# train_batch (Avg. Loss 201.263, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.69it/s]
# test_batch (Avg. Loss 214.667, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.90it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 162
# train_batch (Avg. Loss 199.718, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.04it/s]
# test_batch (Avg. Loss 210.670, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.59it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 163
# train_batch (Avg. Loss 200.198, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.39it/s]
# test_batch (Avg. Loss 207.470, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.03it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 164
# train_batch (Avg. Loss 203.669, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.72it/s]
# test_batch (Avg. Loss 207.752, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.37it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 165
# train_batch (Avg. Loss 199.627, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.66it/s]
# test_batch (Avg. Loss 226.242, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.00it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 166
# train_batch (Avg. Loss 199.358, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.62it/s]
# test_batch (Avg. Loss 209.850, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.53it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 167
# train_batch (Avg. Loss 198.102, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.06it/s]
# test_batch (Avg. Loss 203.879, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 168
# train_batch (Avg. Loss 200.323, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.02it/s]
# test_batch (Avg. Loss 206.997, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 169
# train_batch (Avg. Loss 201.075, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  4.02it/s]
# test_batch (Avg. Loss 224.187, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.76it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 170
# --- EPOCH 171/200 ---
# train_batch (Avg. Loss 201.083, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.07it/s]
# test_batch (Avg. Loss 227.880, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.00it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 171
# train_batch (Avg. Loss 203.266, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.02it/s]
# test_batch (Avg. Loss 204.700, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.63it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 172
# train_batch (Avg. Loss 200.608, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  3.17it/s]
# test_batch (Avg. Loss 206.494, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.55it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 173
# train_batch (Avg. Loss 202.429, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  3.89it/s]
# test_batch (Avg. Loss 210.439, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.21it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 174
# train_batch (Avg. Loss 203.067, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  3.98it/s]
# test_batch (Avg. Loss 208.575, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.62it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 175
# train_batch (Avg. Loss 200.920, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.04it/s]
# test_batch (Avg. Loss 217.099, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.68it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 176
# train_batch (Avg. Loss 201.892, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  4.00it/s]
# test_batch (Avg. Loss 215.758, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.98it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 177
# train_batch (Avg. Loss 203.096, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.04it/s]
# test_batch (Avg. Loss 208.260, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.64it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 178
# train_batch (Avg. Loss 199.625, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.00it/s]
# test_batch (Avg. Loss 213.726, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 179
# train_batch (Avg. Loss 200.535, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.32it/s]
# test_batch (Avg. Loss 213.641, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.14it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 180
# --- EPOCH 181/200 ---
# train_batch (Avg. Loss 201.812, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.41it/s]
# test_batch (Avg. Loss 213.469, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.87it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 181
# train_batch (Avg. Loss 199.480, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.48it/s]
# test_batch (Avg. Loss 204.678, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.96it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 182
# train_batch (Avg. Loss 201.389, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  3.97it/s]
# test_batch (Avg. Loss 210.130, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.80it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 183
# train_batch (Avg. Loss 195.903, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.00it/s]
# test_batch (Avg. Loss 209.266, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 184
# train_batch (Avg. Loss 199.103, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.06it/s]
# test_batch (Avg. Loss 222.396, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 185
# train_batch (Avg. Loss 200.680, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.58it/s]
# test_batch (Avg. Loss 212.302, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.38it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 186
# train_batch (Avg. Loss 197.966, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.70it/s]
# test_batch (Avg. Loss 211.504, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.06it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 187
# train_batch (Avg. Loss 200.743, Accuracy 0.0): 100%|██████████| 15/15 [00:04<00:00,  3.38it/s]
# test_batch (Avg. Loss 212.666, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.84it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 188
# train_batch (Avg. Loss 199.914, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.40it/s]
# test_batch (Avg. Loss 208.033, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  3.26it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 189
# train_batch (Avg. Loss 202.508, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.70it/s]
# test_batch (Avg. Loss 202.719, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.19it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 190
# --- EPOCH 191/200 ---
# train_batch (Avg. Loss 202.312, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.60it/s]
# test_batch (Avg. Loss 203.745, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.42it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 191
# train_batch (Avg. Loss 203.980, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.66it/s]
# test_batch (Avg. Loss 211.125, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.95it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 192
# train_batch (Avg. Loss 200.568, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.63it/s]
# test_batch (Avg. Loss 222.168, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 193
# train_batch (Avg. Loss 199.510, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.59it/s]
# test_batch (Avg. Loss 205.263, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  3.16it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 194
# train_batch (Avg. Loss 201.837, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.59it/s]
# test_batch (Avg. Loss 205.094, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.19it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 195
# train_batch (Avg. Loss 198.864, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.46it/s]
# test_batch (Avg. Loss 210.927, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.17it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 196
# train_batch (Avg. Loss 199.393, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.67it/s]
# test_batch (Avg. Loss 208.908, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.04it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 197
# train_batch (Avg. Loss 198.619, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.51it/s]
# test_batch (Avg. Loss 214.564, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  7.02it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 198
# train_batch (Avg. Loss 198.143, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.04it/s]
# test_batch (Avg. Loss 209.589, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  6.81it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 199
# --- EPOCH 200/200 ---
# train_batch (Avg. Loss 202.106, Accuracy 0.0): 100%|██████████| 15/15 [00:03<00:00,  4.03it/s]
# test_batch (Avg. Loss 214.233, Accuracy 0.0): 100%|██████████| 2/2 [00:00<00:00,  5.86it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 200
# *** Images Generated from best model:

# %% [markdown]
# ## Questions
# <a id=part2_7></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw3/answers.py`.

# %%
from cs236605.answers import display_answer
import hw3.answers

# %% [markdown]
# ### Question 1
#
# What does the $\sigma^2$ hyperparameter (`x_sigma2` in the code) do? Explain the effect of low and high values.

# %%
display_answer(hw3.answers.part2_q1)
# Out:
# **What does the $\sigma^2$ hyperparameter do?**
#
# The $\sigma^2$ hyperparameter allows us to control the relative influence of the data-loss.
# In fact, if we will use a small $sigma^2$ the data-loss effect on the loss value will be higher, and vice-versa.
# The more effect the data-loss has on the loss value we allow less randomness to our generator and expect results
# that resemble the dataset we have.

# %% [markdown]
# ### Question 2
#
# 1. Explain the purpose of both parts of the VAE loss term - reconstruction loss and KL divergence loss.
# 2. How is the latent-space distribution affected by the KL loss term?
# 3. What's the benefit of this?

# %%
display_answer(hw3.answers.part2_q2)
# Out:
# **Loss term and KL divergence:**
#
# 1. The purpose of the reconstruction loss is to increase the probability that the model will reconstruct an image
# that resembles the imaged used in the feature extruction (encoding) phase. What we try to achieve is to increase
# the model's ability to create the kinds of images that exist in the image dataset.
# The purpose of the KL divergence is to measure the distance between the posterior and the prior distributions.
# We want to make sure that our encoder's outputs are distributed in a similar way to the prior distribution,
# which means the distribution of feature vectors in the latent space.
#
# 2. We assume the latent space's distribution is Normal with mean=0 and var=1. By minimizing the KL divergence term we
# try to make the posterior distribution as close as possible to the prior. if we will not try to normalize the decoder's
# values we will end up at the end of training with informed vectors, that each one represents an image from the dataset.
# In fact we try to use normally distributed input vectors to our decoder, which means that we try to use normally
# distributed vectors for the training latent space of our model.
# By constantly comparing the posterior distribution (the encoder's output) to the normal distribution we make sure
# that the features created by the encoder in the features vectors are the one's necessary to create an image that belongs
# to our instance space. If our encoder will create too many features, the vectors encoded from the instance space will
# not be normally distributed, and therefor we will have high KL divergence value.
#
# 3. If we wouldn't use the KL divergence term at all, at the end of the training we will have a decoder that gets a
# features vector and returns one of the images in the dataset. In fact, the benefit of using the KL divergence term is to
# prevent dataset over-fitting.
#
# An equation: $e^{i\pi} -1 = 0$
